# %% [markdown]
# ![image.png](attachment:7bcc8ef7-b982-46d7-a8f7-6231d2cb94c3.png)

# %% [markdown]
# ### Тут настраивается вывод и ввод из терминала
# ![image.png](attachment:a1ed5676-ccad-4035-b76f-5cc98ff937fe.png)

# %% [markdown]
# ### Т.к. char помимо символа представляет из себя число ASCII, то тип переменной ставим int
# ![image.png](attachment:34808bce-3cc2-4ea4-b923-3e98f275d3d3.png)

# %% [markdown]
# ### При запуске программы буферы ввода и вывода пустые

# %% [markdown]
# ![image.png](attachment:27943f2b-e952-466d-aaa5-3323e36b98cb.png)

# %% [markdown]
# ![image.png](attachment:0718f6cb-77bd-4fa7-96bf-e3b9fa9a5abc.png)

# %% [markdown]
# ![image.png](attachment:b12f4eda-5d31-4416-b909-dbe95f8b5f65.png)

# %% [markdown]
# ![image.png](attachment:a5de41d6-ea15-4bf1-a212-b7f7c30f832e.png)

# %% [markdown]
# ![image.png](attachment:50d067b0-1db0-4ac6-8944-e13d768aa77f.png)

# %% [markdown]
# ![image.png](attachment:da9b0c2f-2030-49f1-b6e6-8d6a4802053e.png)
# ![image.png](attachment:cef1ee75-d62d-4d35-80bd-a00d5fe6ab50.png)

# %% [markdown]
# ![image.png](attachment:151eeef5-0373-4b36-8cc9-acd1b1ee8b58.png)
