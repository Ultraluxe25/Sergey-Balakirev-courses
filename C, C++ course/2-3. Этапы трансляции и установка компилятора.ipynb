# %% [markdown]
# ![image.png](attachment:70633a16-4b25-408e-a7d4-ec89ef37bfb8.png)

# %% [markdown]
# **Тестовый препроцессор** - его задача в программе найти все, так называемые, директивы (указания) для этого препроцессора и выполнить их.

# %% [markdown]
# Версия С99 наиболее "чистая"

# %% [markdown]
# ![image.png](attachment:4c3ad5da-fa3b-4b30-a734-db72f6d569ac.png)

# %% [markdown]
# ![image.png](attachment:e3e757e3-cf34-4488-8339-d31ae70a5070.png)

# %% [markdown]
# ![image.png](attachment:fca95452-a653-4b48-b54e-dcfe6eabe9b0.png)

# %% [markdown]
# ![image.png](attachment:01a7d9dd-c568-43a5-bd50-8c10f0ec2d9d.png)

# %% [markdown]
# Самый популярный компилятор C - **gcc**. [Ссылка на скачивание компилятора](https://github.com/selfedu-rus/others/blob/main/mingw-get-setup.exe)

# %% [markdown]
# ![image.png](attachment:5318f3af-a7da-43ab-8221-bfa4e9a74f94.png)

# %% [markdown]
# ![image.png](attachment:d2f95690-9105-4465-ac5d-11c5ec166856.png)

# %% [markdown]
# ![image.png](attachment:68935bfc-f6ea-4290-959d-a9a53c632544.png)

# %% [markdown]
# # [Ссылка на настройку компилятора](https://proproprogs.ru/c_base/c_ustanovka-kompilyatora-gcc-i-visual-studio-code-na-os-windows)

# %% [markdown]
# ![image.png](attachment:3a5e3ec0-242f-4913-b469-973c86ed7f9e.png)

# %% [markdown]
# ![image.png](attachment:de06b37a-9607-4e33-875c-9c48b05ef683.png)

# %% [markdown]
# ![image.png](attachment:eef3cbde-ad3f-413a-9d98-60427c95c36a.png)

# %% [markdown]
# ![image.png](attachment:f19a9c8b-6cce-4031-ad05-e93209e97ce1.png)
