# %% [markdown]
# ![image.png](attachment:d2c00285-7ed7-4045-a3d2-f87f50fdef4d.png)

# %% [markdown]
# ### В современных компьютерах каждой запущенной программе отводится своя независимая рабочая область памяти.

# %% [markdown]
# ![image.png](attachment:01b0b3b0-128c-4179-905d-9417edbb2319.png)

# %% [markdown]
# ```C
# #include <stdio.h>
#
# int main(void) {
#     char byte_memory;
#     byte_memory = 100;
#     char a;
#     a = byte_memory;
#
#     return 0;
# }

# %% [markdown]
# ### Расположение переменных определяет менеджер памяти ОС. Когда в программе объявляется очередная переменная, то ОС располагает ее в найденной свободной последовательности ячеек.

# %% [markdown]
# ### Имя переменной - это название хранилища, в котором хранится, например число.

# %% [markdown]
# ### В языке Си переменные – это непосредственно хранилища данных, поэтому в момент присваивания происходит копирование информации из одного хранилища в другое.

# %% [markdown]
# ![image.png](attachment:8806c9c1-849f-47d5-adcc-4fac6d5e582f.png)
# ### Выше представлены максимальные длины названия переменных

# %% [markdown]
# ![image.png](attachment:98c129d9-fb48-45f5-a411-0f10e83f18d1.png)
# ### Переменные в Си принято записывать малыми буквами

# %% [markdown]
# ![image.png](attachment:9ad45c80-19c9-4abd-921a-f8054abe728c.png)

# %% [markdown]
# ### Почему бы эти размеры строго не определить и договориться использовать вполне определенные значения? Но на это есть одно веское основание. Вспоминаем, язык Си разработан как заменитель языка Ассемблер и программы на Си должны наилучшим образом переводиться в машинный код. А машинный код жестко привязан к архитектуре компьютера: разрядности регистров процессора, шины и ячеек памяти. Например, тип char введен для работы с отдельными ячейками памяти. Если в компьютере они составляют 8 бит, то и компилятор будет описывать тип char восьмью битами. Если же представить вычислительную технику с ячейками в 12 бит, то логично тип char также сделать 12-битным. Вот почему размеры типов жестко не регламентируются спецификациями языка Си.

# %% [markdown]
# ### Вплоть до появления 64-битных процессоров он совпадал по размеру с машинным словом процессора. Поэтому в эпоху 16-битных процессоров int составлял 16 бит (2 байта), при 32-битных – 32 бита (4 байта). А вот при появлении 64-битных он остался 32-битным. Опять же, казалось бы, давайте его по логике увеличим до 64 бит? Но здесь возникла другая проблема. Если int сделать 64-битным, то у нас не будет целочисленного типа в 32 бита. Вводить новый было бы неразумно, т.к. существует масса ранее уже написанных программ с использованием только таких типов данных. А компиляторы стараются создавать так, чтобы программы на Си были переносимыми, то есть, чтобы их можно было впоследствии перекомпилировать под другую платформу или для другого процессора.

# %% [markdown]
# ![image.png](attachment:77f7baea-3fc9-4ad5-883a-d0c1fb9ac3ba.png)

# %% [markdown]
# ### Модификаторы знака
# ![image.png](attachment:1329ed62-066d-4aa3-a999-d887781a6af8.png)

# %% [markdown]
# ![image.png](attachment:306a9ad8-2783-4a86-98b0-c162e12e1fef.png)

# %% [markdown]
# ### Только для типа char нужно указывать явно. Можно для других типов явно прописать unsigned

# %% [markdown]
# ### Модификаторы знака запрещено прописывать вместе с вещественными числами. Вещественные числа всегда знаковые

# %% [markdown]
# ### В основном использовать int и double, а к типам short и float обращаться только если в программе много переменных (от 1000) с небольшим значением.

# %% [markdown]
# ![image.png](attachment:87c98f4b-6868-44fe-93ec-14c9b558d6ff.png)

# %% [markdown]
# ![image.png](attachment:3009295b-5967-4262-ae12-28f59b442bc1.png)

# %% [markdown]
# ![image.png](attachment:191f84ec-6e84-46da-94bc-b885fd29fd89.png)

# %% [markdown]
# ![image.png](attachment:8dc8e640-db2c-484f-be6b-e63f9814c6e0.png)

# %% [markdown]
# ![image.png](attachment:b1c7fa7d-3007-4bdd-be4a-e53532681045.png)

# %% [markdown]
# ![image.png](attachment:95522376-c7c3-4664-8285-303066d21e1b.png)

# %% [markdown]
# ![image.png](attachment:9f2be1fd-58d4-4846-a0dc-6753421daea7.png)

# %% [markdown]
# ![image.png](attachment:aa397e76-481b-4c9f-9782-63d180106673.png)

# %% [markdown]
# ![image.png](attachment:207ec507-c1c3-4f08-a0da-74916ad1b732.png)

# %% [markdown]
# ![image.png](attachment:5f153a82-dbef-4805-b937-459c1dcfe224.png)
