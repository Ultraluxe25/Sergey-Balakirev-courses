# %% [markdown]
# ![image.png](attachment:645d167f-f7cd-4e7f-b536-13eb6da2b667.png)

# %% [markdown]
# ### Операция присваивания копирует значение из правого операнда в левый операнд. Соответственно левый операнд должен явно или косвенно определять ячейки памяти, куда можно занести значение, указанное в правой части.

# %% [markdown]
# ### Определение значения переменной сразу в момент ее объявления - инициализация
# ![image.png](attachment:e49ebd1b-5024-47de-909a-6f14aeda1865.png)

# %% [markdown]
# ### В программировании явно прописанные числовые значения называются числовыми литералами и представляется как целочисленная константа типа int

# %% [markdown]
# ![image.png](attachment:39d533bc-b6c1-4430-b364-5eb2b9e7e2e4.png)
# ### 0x говорит о том, что перед нами число в 16-ричной системе, а 0 перед числом говорит нам о том, что перед нами число в 8-ричной системе

# %% [markdown]
# ### Литералы представляют собой константы, включаемые непосредственно в текст программы.

# %% [markdown]
# ![image.png](attachment:0460f1a9-1797-4660-a819-4e235b507787.png)

# %% [markdown]
# ![image.png](attachment:b55be8e0-5399-46f5-80af-47f0dbf0ca8c.png)
# # Каждому символу типа char ставится в соответствии ASCII число

# %% [markdown]
# ![image.png](attachment:888c2e2c-098a-4da4-9e76-99ac5b471337.png)

# %% [markdown]
# ### В этом случае компилятор в переменной ch хранит число 100, но при этом может представить его как символ или как число

# %% [markdown]
# ![image.png](attachment:2392bf4b-0ef7-40b2-b1a0-4eb0bb716850.png)
# ### Такое число всегда будет иметь тип double

# %% [markdown]
# ![image.png](attachment:0a9158a1-feca-4d5e-9e9a-c7eb77fc9b67.png)

# %% [markdown]
# ![image.png](attachment:0ae012a9-b6b0-4332-a228-4a6c82eff717.png)
# ![image.png](attachment:3621eddc-08cf-4091-b30d-255208dc3ff2.png)

# %% [markdown]
# ![image.png](attachment:8979d2ff-a4d0-4931-bdc3-6fcad5dbf9a4.png)

# %% [markdown]
# ![image.png](attachment:dbc223c7-6664-4eb3-86b8-7ba2a179f198.png)

# %% [markdown]
# ![image.png](attachment:4b35bd24-eed3-457e-a473-a4b8058aa509.png)

# %% [markdown]
# ![image.png](attachment:44874559-ecf5-4646-be9a-6b845a3d0570.png)

# %% [markdown]
# ![image.png](attachment:7333789f-2215-4575-9696-dd694a0f41a6.png)

# %% [markdown]
# ![image.png](attachment:4e7ccc20-535e-49e5-bf1c-fa2df3416824.png)

# %% [markdown]
# ![image.png](attachment:35d05382-d107-4de7-afc3-fa0b3116f872.png)

# %% [markdown]
# ![image.png](attachment:dc72fb4d-6249-4e08-b8ca-fde792c3dd9b.png)

# %% [markdown]
# ![image.png](attachment:88bcaad6-a0dc-49f4-b83b-dc4a4ab67e00.png)

# %% [markdown]
# ![image.png](attachment:c4a0da8a-192f-43f2-a83f-4b6a32095924.png)
