# %% [markdown]
# ![image.png](attachment:19ce38e5-6da1-454e-aff9-e2f5d0d86b6c.png)

# %% [markdown]
# ### Docker появился в 2013 году

# %% [markdown]
# ![image.png](attachment:57653bf0-57f0-4f28-adfe-9f746eaaca52.png)

# %% [markdown]
# ![image.png](attachment:e29ecb86-4bfd-43d9-a09f-1f61772fa1d0.png)

# %% [markdown]
# ![image.png](attachment:d9e149d0-9344-488d-92bb-3cd263f8528d.png)
# ### Контейнер - это изолированная среда со своей операционной системой

# %% [markdown]
# ![image.png](attachment:a627ba58-f1a2-4bd3-b12f-4700c0ecccd4.png)
