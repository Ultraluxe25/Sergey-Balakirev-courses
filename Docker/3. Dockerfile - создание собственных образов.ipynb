# %% [markdown]
# ![image.png](attachment:245bdc1c-80f5-4da4-b81d-db8142879f3d.png)

# %% [markdown]
# ![image.png](attachment:d7a4be79-adaf-4325-831f-54bc247e100c.png)

# %% [markdown]
# ![image.png](attachment:77c22335-fb19-4505-a186-17992667eaa6.png)

# %% [markdown]
# ### Оказывается с Docker можно работать из терминала VS Code
# ![image.png](attachment:e228c8b6-9a92-4f90-9bd1-9ce5268bd9bb.png)

# %% [markdown]
# ### Git коммиты, виды:
# ![image.png](attachment:eda05067-697f-4a1a-b2b1-99b4fe927b9c.png)
