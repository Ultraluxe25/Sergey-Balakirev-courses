# %% [markdown]
# ![image.png](attachment:33870b2c-a9a0-497b-82d3-43c41bc961a3.png)

# %% [markdown]
# ![image.png](attachment:c021aacc-d56f-4c98-a85a-f279067e6b7c.png)

# %% [markdown]
# ### Многие контейнеры после запуска выполняют свою работу и закрываются автоматически

# %% [markdown]
# ### Попытка создать контейнер с таким же именем вызовет ошибку. `docker start` вызывает уже созданные контейнер

# %% [markdown]
# ![image.png](attachment:c339fdbb-cf44-479a-95dd-a3e21906fde0.png)

# %% [markdown]
# ![image.png](attachment:e46ef26c-bf8a-4641-8c12-678da9cc11c9.png)

# %% [markdown]
# ### Для удаления всех контейнеров (остановленных)
# ![image.png](attachment:0299059b-fe66-4d42-98c7-9dd37ef8e039.png)

# %% [markdown]
# ### Для удаления образа, чей тег не `latest` мы явно должны его указать чтобы не получить ошибку
# ![image.png](attachment:b2dce505-0e91-4447-b97e-84e6e9ebbfda.png)

# %% [markdown]
# ### Мы не можем удалить образ если у него есть контейнеры, даже остановленные

# %% [markdown]
# ![image.png](attachment:5fc32c1c-8051-43ee-a172-3424e42b6a2b.png)
# ### Так можно удалить контейнер сразу после того как он выключится

# %% [markdown]
# ### Команда справки и варианты флагов
# ![image.png](attachment:924e3806-22c4-45c3-ad19-654a82b0129d.png)
