# %% [markdown]
# ![image.png](attachment:441d3b9b-9ba7-4732-9fb9-bd1b6d3ffc4b.png)

# %% [markdown]
# ### Отдельные компоненты Docker можно собрать только для Linux, для других ОС нужно ставить целиком Docker Desktop

# %% [markdown]
# ![image.png](attachment:66d22bfa-5558-4bea-8b58-913db114e346.png)

# %% [markdown]
# ![image.png](attachment:4bc55eb2-2816-4982-b457-a475d7cf4426.png)

# %% [markdown]
# ### Путь, по которому будут храниться скачанные докер образы
# ![image.png](attachment:2ccb4858-f07b-43ea-95be-695c23498997.png)
