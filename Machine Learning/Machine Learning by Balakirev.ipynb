# %% [markdown]
# ![image.png](attachment:ee134d2b-fb62-4e4d-bdf7-e5b629d955c2.png)

# %% [markdown]
# ![image.png](attachment:e1f7eac4-59e6-42f1-9733-d7198005adb6.png)

# %% [markdown]
# ![image.png](attachment:82922365-6716-4d3c-9e86-341dcde55c4e.png)

# %% [markdown]
# ![image.png](attachment:340ab433-cd93-4c44-9b80-288ae9560d4c.png)
